# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_moons


# default plot config
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,8)
plt.rcParams['figure.dpi'] = 150
sns.set()

from IPython.display import display, Latex, Markdown

# %%
X, y = make_moons(n_samples=100, shuffle=False, noise=0.6, random_state=None)
sns.scatterplot(
    x=X[:, 0], y=X[:, 1], hue=y, marker="o", s=25, edgecolor="k", legend=True
).set_title("Data")
plt.show()

data = pd.DataFrame(X)
data.head()
# Out:
#           0         1
# 0  1.002254  0.707576
# 1  1.957295 -0.158950
# 2  0.652424 -0.487970
# 3  1.806703  0.620286
# 4  0.603266  0.075404
